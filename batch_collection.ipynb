# %% [markdown]
# This notebook provides the end-to-end workflow for collecting historical question responses through OpenRouter. It uses the shared `collect_pipeline.py` module to manage API clients, load the question bank, and write JSONL output to `data/responses/`. Run the notebook to execute the batch collection for all supported models using the configured OpenRouter credentials in `.env`.

# %% [markdown]
# Batch collection for all configured models. This notebook delegates the work to collect_pipeline.py, which queries each supported OpenRouter model alias and writes JSONL responses to data/responses/.

# %% [markdown]
# This notebook runs all models using collect_pipeline.py. Outputs are written to data/responses/<model>.jsonl for each supported model alias. Make sure .env contains your OpenRouter API key and figures/question_bank.csv has the question bank.

# %%
from collect_pipeline import collect_models, load_environment

load_environment(".env")

# %%
collect_models(models="all")
